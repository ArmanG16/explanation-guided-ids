# %% [markdown]
# Setting paths and imports

# %%
import os
import sys

BASE_DIR = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.insert(0, BASE_DIR)
sys.path.insert(0, os.path.join(BASE_DIR, "pyIDS"))

# %% [markdown]
# Preproccessing the Beth Dataset

# %%
from src.Beth_Dataset_Example.Preprocess_Beth import Preprocess_Beth
Preprocess_Beth()
# Out:
# 13:58:21, Preprocessing_Func.py: Saved c:\Users\mrclo\OneDrive\Desktop\Projects\explanation-guided-ids\data/processed/bethdataset\processed_labelled_2021may-ip-10-100-1-4.csv | Rows: 485241 | Cols: 13
# 13:58:21, Preprocessing_Func.py: Saved c:\Users\mrclo\OneDrive\Desktop\Projects\explanation-guided-ids\data/processed/bethdataset\processed_labelled_2021may-ip-10-100-1-4-dns.csv | Rows: 269 | Cols: 12
# 13:58:26, Preprocessing_Func.py: Saved c:\Users\mrclo\OneDrive\Desktop\Projects\explanation-guided-ids\data/processed/bethdataset\processed_labelled_2021may-ip-10-100-1-26.csv | Rows: 378424 | Cols: 12
# 13:58:26, Preprocessing_Func.py: Saved c:\Users\mrclo\OneDrive\Desktop\Projects\explanation-guided-ids\data/processed/bethdataset\processed_labelled_2021may-ip-10-100-1-26-dns.csv | Rows: 269 | Cols: 12
# ...

# %% [markdown]
# Training on the Beth dataset

# %%
# from src.Beth_Dataset_Example.Train_On_Beth_Dataset import Beth_Train
# Beth_Train(1000000)
# !sbatch run_beth.slurm
# Out:
# Submitted batch job 1666405

# %% [markdown]
# Check Training Status

# %%
# !squeue -u $USER
# Out:
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)

# %% [markdown]
# Training the Beth dataset and creating the learning curve on one CSV file

# %%
from src.utils.Learning_Curve_Func import make_learning_curve

csv_path = "data/processed/bethdataset/processed_labelled_2021may-ip-10-100-1-4-dns.csv"
csv_path = os.path.join(BASE_DIR, csv_path)
make_learning_curve(csv_path)
